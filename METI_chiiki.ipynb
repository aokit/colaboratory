# %% [markdown]
# <a href="https://colab.research.google.com/github/aokit/colaboratory/blob/master/METI_chiiki.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# -*- coding: utf-8 -*-

import pprint
import requests
from html.parser import HTMLParser


class Parser(HTMLParser):
    def __init__(self):
        HTMLParser.__init__(self)
        self.title = False
        self.link = False
        self.data = []

    def handle_starttag(self, tag, attrs):
        attrs = dict(attrs)
#       if tag == "h2" and "class" in attrs and attrs['class'] == "esc-lead-article-title":
        if tag == "h1" :
            self.data.append({})
            self.title = True
            self.link = True
            '''            
        if tag == "a" and self.link == True:
            self.data[-1].update({"link": attrs["href"]})
            '''

    def handle_data(self, data):
        True
'''
        if self.title == True or self.link == True:
            self.data[-1].update({"title": data})
            self.title = False
            self.link = False
'''

def main():
    payload = {"topic" : "t"}
    # r = requests.get('https://news.google.com/news/section', params=payload)
    r = requests.get('http://www.meti.go.jp/policy/anpo/apply08.html', params=payload)
    # pprint.pprint(r.text)
    parser = Parser()
    parser.feed(r.text)
    parser.close()

    pprint.pprint(parser.data)
    for i in parser.data:
#       print("Title: " + i["title"], "\nLink: " + i["link"] + "\n")
#       print("Title: " + i["title"], "\n")
#       print("Title: " , "\n")
        print(type(i))
        pprint.pprint(i)
        for k in i:
            print(k)
#       s = i["title"]
#       s = i["h1"]
#       b = s.encode('cp932' , "ignore")
#       s_after = b.decode('cp932')
#       print(": " + s_after, "\n")


if __name__ == '__main__':
    main()
# Out:
# []

# %%
# -*- coding: utf-8 -*-

import pprint
import requests
from html.parser import HTMLParser


class Parser(HTMLParser):
    def __init__(self):
        HTMLParser.__init__(self)
        self.title = False
        self.link = False
        self.data = []

    def handle_starttag(self, tag, attrs):
        attrs = dict(attrs)
        if tag == "h2" and "class" in attrs and attrs['class'] == "esc-lead-article-title":
            self.data.append({})
            self.title = True
            self.link = True

        if tag == "a" and self.link == True:
            self.data[-1].update({"link": attrs["href"]})

    def handle_data(self, data):
        if self.title == True or self.link == True:
            self.data[-1].update({"title": data})
            self.title = False
            self.link = False


def main():
    payload = {"topic" : "t"}
    # r = requests.get('https://news.google.com/news/section', params=payload)
    # r = requests.get('https://news.google.com/?hl=ja&gl=JP&ceid=JP:ja', params=payload)
    r = requests.get('https://news.google.com/')
    pprint.pprint(r.text)
    parser = Parser()
    parser.feed(r.text)
    parser.close()

    for i in parser.data:
        print("Title: " + i["title"], "\nLink: " + i["link"] + "\n")


if __name__ == '__main__':
    main()

# %%
import requests, bs4
# res = requests.get('https://tonari-it.com')
res = requests.get('http://www.meti.go.jp/policy/anpo/apply08.html')
res.raise_for_status()
#  soup = bs4.BeautifulSoup(res.text, "html.parser")
soup = bs4.BeautifulSoup(res.content, "html.parser")
rr=soup.title
tt=pprint.pformat(rr)
# ss=tt.encode('cp932' , "ignore")
# uu=ss.decode('cp932')
# print(soup.title)
# print(uu)
# print(soup.h1)
# print(soup.td)
# print(soup.strong)
# print(soup.name)
# print(soup.a)
# print(soup.td)
'''for a in soup.find_all('a'):
      print(a.get('href')) 
'''
for a in soup.find_all('a'):
      print(a.get('name'))

# %%
### -*- coding:utf-8 -*-
# METI_chiiki.py

# https://qiita.com/hujuu/items/b0339404b8b0460087f9
# これを参考にさせていただきました。ありがとうございます。

import pprint
import csv
# from urllib.request import urlopen
import requests
from bs4 import BeautifulSoup

#URLの指定
# html = urlopen("https://www.oreilly.co.jp/ebook/")
'''
html = urlopen("http://www.meti.go.jp/policy/anpo/apply08.html")
bsObj = BeautifulSoup(html, "html.parser")
# urlopenだとうまく動かないので、requests.get で .content を得るようにしました。
# これは
# https://orangain.hatenablog.com/entry/encoding-in-requests-and-beautiful-soup
# これを参考にさせていただきました。ありがとうございます。
# chardet も入れておいたほうがいいのかもしれませんが、今は入れてません。
'''

res = requests.get('http://www.meti.go.jp/policy/anpo/apply08.html')
res.raise_for_status()
bsObj = bs4.BeautifulSoup(res.content , "html.parser")

#テーブルを指定
# table = bsObj.findAll("table",{"class":"tablesorter"})[0]
tables = bsObj.findAll("table",{"class" : "style71"})

csvFileName ='chiiki_work.csv'

csvFile = open(csvFileName , 'wt', newline = '', encoding = 'utf-8')
writer = csv.writer(csvFile)

try:
  for table in tables:
    rows = table.findAll("tr")
    for row in rows:
        csvRow = []
        for cell in row.findAll(['td', 'th']):
            # csvRow.append(cell.get_text().lstrip().replace('"',''))
            # もともとのページの作りが、文字列の前後がわりと雑に
            # 空白などが入っていて、それもここで切りおとす。
            csvRow.append(cell.get_text().lstrip().rstrip())
        # print(csvRow[0])
        listRow = csvRow[0].replace('、',',').split()
        pprint.pprint(listRow)
        # writer.writerow(csvRow)
        # writer.writerow(pprint.pformat(listRow))
        
finally:
    csvFile.close()

with open(csvFileName , 'rt') as file:
  s = file.read()
  print(s)

# %%
### -*- coding:utf-8 -*-
# METI_chiiki.py

# 対象とする Web ページから決める記述は以下の３行。以下は
# 経産省の国と地域のページから地域の定義表を取り出すため
# に必要となる情報
Surl = "http://www.meti.go.jp/policy/anpo/apply08.html"
Sdescription = "table"
Ddescription = {"class" : "style71"}

# https://qiita.com/hujuu/items/b0339404b8b0460087f9
# これを参考にさせていただきました。ありがとうございます。

import pprint
import csv
import requests
import bs4
import hashlib

# URLを指定してコンテンツを取り出す
#
'''
html = urlopen("http://www.meti.go.jp/policy/anpo/apply08.html")
bsObj = BeautifulSoup(html, "html.parser")
# urlopenだとうまく動かないので、requests.get で .content を得るようにしました。
# これは
# https://orangain.hatenablog.com/entry/encoding-in-requests-and-beautiful-soup
# これを参考にさせていただきました。ありがとうございます。
# chardet も入れておいたほうがいいのかもしれませんが、今は入れてません。
'''
# 文法解析されたコンテンツを bsObj に入れておく
# Surl = "http://www.meti.go.jp/policy/anpo/apply08.html"
res = requests.get(Surl)
res.raise_for_status()
bsObj = bs4.BeautifulSoup(res.content , "html.parser")

# テーブルを指定
# table = bsObj.findAll("table",{"class":"tablesorter"})[0]
# タグとクラスが該当するテーブルを tables に入れておく。
# これは、WEBページの記述に依存するので都度調べる必要がある。
# Sdescription = "table"
# Ddescription = {"class" : "style71"}
tables = bsObj.findAll(Sdescription, Ddescription )

csvFileName ='chiiki_work.csv'

csvFile = open(csvFileName , 'wt', newline = '', encoding = 'utf-8')
writer = csv.writer(csvFile)

try:
  # 地域名（『と地域』とか）をキーとして国名のリストを値とした辞書
  dictChiiki = {}
  # 国名（『英国』とか）をキーとして属している地域のリスト（['と地域']とか）を値とした辞書
  dictCountry = {}

  # tables の要素としてひとつひとつの table ごとに
  for table in tables:

    # タグ《tr》により行（rows）を検出して
    rows = table.findAll("tr")
    
    '''
# 行の処理（１行おきに定義地域名だけのリストと当該地域のリスト）を
# 制御するための制御変数を｛■初期化：□更新｝
    '''
    coline = 0
    listRow1 =[]    
    
    # rows の要素としてのひとつひとつの row ごとに
    for row in rows:
      
      '''
# 行の処理（１行おきに定義地域名だけのリストと当該地域のリスト）を
# 制御するための制御変数を｛□初期化：■更新｝
      '''
      coline = coline + 1      
            
      # セルを csvRow にリストアップしていく
      # （実際には今回の対象の表では行あたりひとつのセルしかないが）
      csvRow = []
      for cell in row.findAll(['td', 'th']):
        # もともとのページの作りが、文字列の前後がわりと雑に
        # 空白などが入っていて邪魔なので、それらをここで切りおとす。
        csvRow.append(cell.get_text().lstrip().rstrip())
        # 行あたりのセルがひとつなので、結局、リストの最初の要素である
        # csvRow[0] （中身は表のセルに記載されていた文字列）だけを処理
        # すればよいのだが、それが地域の定義名（『と地域』とか）の場合
        # も、その地域に含まれる国名などを『、』で区切った文字列である
        # 場合もある。後者の場合だけ『、』が含まれているので、結局、
        # 毎回、『,』で区切って split() でリストにしておく。リストの
        # 要素が国名等であるがその前後の空白などは閉包で要素に対して
        # strip しておく。
        listRow0 = listRow1
        listRow1 = [ x.strip() for x in csvRow[0].split("、") ]
        # print(coline)
        # pprint.pprint(listRow1)
        
        # ２行分そろったら
        if (coline%2==0) :
          # リストとしてどうなっているかちょっと見てみる。
          # pprint.pprint(listRow0)
          # pprint.pprint(listRow1)
          
          # 辞書に登録
          # dictChiiki[listRow0[0]] = len(listRow1)
          dictChiiki[listRow0[0]] = listRow1
          
          # 逆引き辞書にも登録
          Schiiki = listRow0[0]
          for Scountry in listRow1 :
            if (Scountry in dictCountry.keys()):
              Lchiiki = dictCountry[Scountry]
            else:
              Lchiiki = []
            Lchiiki.append(Schiiki)
            dictCountry[Scountry] = Lchiiki
        
        # writer.writerow(csvRow)
        # writer.writerow(pprint.pformat(listRow))
#
finally:
    csvFile.close()
#
with open(csvFileName , 'rt') as file:
  s = file.read()
  print(s)
#
#
# pprint.pprint(dictChiiki)
# pprint.pprint(dictCountry)
print( hashlib.md5(pprint.pformat(dictCountry).encode()).hexdigest() )
# b1d74ca20ed9e0efed3ab6c5f21c991d
# pprint.pprint(dictCountry)
# s_country = 'アメリカ合衆国'
# s_country = '北朝鮮'
# s_country = '中国'
# s_country = '中華人民共和国'
s_country = ''

if len(s_country)==0 :
  print('====国名等は以下のどれかでしょうか====')
  for k in dictCountry.keys() :
    print(k)
  print('====国名等の逆引き辞書は以下の通り====')
  pprint.pprint(dictCountry)
else:
  print(s_country)
  if ( s_country in dictCountry.keys() ):
    pprint.pprint(dictCountry[s_country])
  else:
    print('⇒（該当国名がありません）その他の地域')
    pprint.pprint(dictCountry['その他の地域'])
    # print(dictCountry['その他の地域'])

# %%
### -*- coding:utf-8 -*-
# METI_chiiki.py

# ＜技術＞http://www.meti.go.jp/policy/anpo/apply07.html
# ＜仕向＞http://www.meti.go.jp/policy/anpo/apply08.html
# ＜貨物＞http://www.meti.go.jp/policy/anpo/apply09.html
# 対象とする Web ページから決める記述は以下の３行。以下は
# 経産省の国と地域のページから地域の定義表を取り出すため
# に必要となる情報
Surl = "http://www.meti.go.jp/policy/anpo/apply08.html"
Sdescription = "table"
Ddescription = {"class" : "style71"}

# https://qiita.com/hujuu/items/b0339404b8b0460087f9
# これを参考にさせていただきました。ありがとうございます。

import pprint
import csv
import requests
import bs4
import hashlib

''' ==== requirements.txt
# Function dependencies, for example:
# package>=version
# -# google-auth
google-api-python-client
oauth2client
bs4
'''

def print_chiiki(s_country):
  # URLを指定してコンテンツを取り出す
  #
  '''
html = urlopen("http://www.meti.go.jp/policy/anpo/apply08.html")
bsObj = BeautifulSoup(html, "html.parser")
# urlopenだとうまく動かないので、requests.get で .content を得るようにしました。
# これは
# https://orangain.hatenablog.com/entry/encoding-in-requests-and-beautiful-soup
# これを参考にさせていただきました。ありがとうございます。
# chardet も入れておいたほうがいいのかもしれませんが、今は入れてません。
  '''
  # 文法解析されたコンテンツを bsObj に入れておく
  # Surl = "http://www.meti.go.jp/policy/anpo/apply08.html"
  res = requests.get(Surl)
  res.raise_for_status()
  bsObj = bs4.BeautifulSoup(res.content , "html.parser")

  # テーブルを指定
  # table = bsObj.findAll("table",{"class":"tablesorter"})[0]
  # タグとクラスが該当するテーブルを tables に入れておく。
  # これは、WEBページの記述に依存するので都度調べる必要がある。
  # Sdescription = "table"
  # Ddescription = {"class" : "style71"}
  tables = bsObj.findAll(Sdescription, Ddescription )

  # csvFileName ='chiiki_work.csv'
  # csvFile = open(csvFileName , 'wt', newline = '', encoding = 'utf-8')
  # writer = csv.writer(csvFile)

  try:
    # 地域名（『と地域』とか）をキーとして国名のリストを値とした辞書
    dictChiiki = {}
    # 国名（『英国』とか）をキーとして属している地域のリスト（['と地域']とか）を値とした辞書
    dictCountry = {}

    # tables の要素としてひとつひとつの table ごとに
    for table in tables:

      # タグ《tr》により行（rows）を検出して
      rows = table.findAll("tr")
    
      '''
# 行の処理（１行おきに定義地域名だけのリストと当該地域のリスト）を
# 制御するための制御変数を｛■初期化：□更新｝
      '''
      coline = 0
      listRow1 =[]    
    
      # rows の要素としてのひとつひとつの row ごとに
      for row in rows:
      
        '''
# 行の処理（１行おきに定義地域名だけのリストと当該地域のリスト）を
# 制御するための制御変数を｛□初期化：■更新｝
        '''
        coline = coline + 1      
            
        # セルを csvRow にリストアップしていく
        # （実際には今回の対象の表では行あたりひとつのセルしかないが）
        csvRow = []
        for cell in row.findAll(['td', 'th']):
          # もともとのページの作りが、文字列の前後がわりと雑に
          # 空白などが入っていて邪魔なので、それらをここで切りおとす。
          csvRow.append(cell.get_text().lstrip().rstrip())
          # 行あたりのセルがひとつなので、結局、リストの最初の要素である
          # csvRow[0] （中身は表のセルに記載されていた文字列）だけを処理
          # すればよいのだが、それが地域の定義名（『と地域』とか）の場合
          # も、その地域に含まれる国名などを『、』で区切った文字列である
          # 場合もある。後者の場合だけ『、』が含まれているので、結局、
          # 毎回、『,』で区切って split() でリストにしておく。リストの
          # 要素が国名等であるがその前後の空白などは閉包で要素に対して
          # strip しておく。
          listRow0 = listRow1
          listRow1 = [ x.strip() for x in csvRow[0].split("、") ]
          # print(coline)
          # pprint.pprint(listRow1)
        
          # ２行分そろったら
          if (coline%2==0) :
            # リストとしてどうなっているかちょっと見てみる。
            # pprint.pprint(listRow0)
            # pprint.pprint(listRow1)
          
            # 辞書に登録
            # dictChiiki[listRow0[0]] = len(listRow1)
            dictChiiki[listRow0[0]] = listRow1
          
            # 逆引き辞書にも登録
            Schiiki = listRow0[0]
            for Scountry in listRow1 :
              if (Scountry in dictCountry.keys()):
                Lchiiki = dictCountry[Scountry]
              else:
                Lchiiki = []
              Lchiiki.append(Schiiki)
              dictCountry[Scountry] = Lchiiki
        
          # writer.writerow(csvRow)
          # writer.writerow(pprint.pformat(listRow))
  #
  finally:
    # csvFile.close()
    print('done')
  #
  s_ret = ""
  if len(s_country)==0 :
    s_ret = '====…?country=国名 で国名等を指定してください。====\n'
    s_ret = s_ret + '====国名等は以下のどれかでしょうか====\n'
    for k in dictCountry.keys() :
      s_ret = s_ret + k + '\n'
    s_ret = s_ret + '====国名等の逆引き辞書は以下の通り====\n'
    s_ret = s_ret + pprint.pformat(dictCountry)
  else:
    s_ret = s_country + ' '
    if ( s_country in dictCountry.keys() ):
      s_ret = s_ret + pprint.pformat(dictCountry[s_country])
    else:
      s_ret = s_ret + '⇒（該当国名がありません）その他の地域\n'
      s_ret = s_ret + pprint.pformat(dictCountry['その他の地域'])
    #
    # print(dictCountry['その他の地域'])
  #
  return s_ret
#
'''
with open(csvFileName , 'rt') as file:
  s = file.read()
  print(s)
'''
#
#
# pprint.pprint(dictChiiki)
# pprint.pprint(dictCountry)
#print( hashlib.md5(pprint.pformat(dictCountry).encode()).hexdigest() )
# b1d74ca20ed9e0efed3ab6c5f21c991d
# pprint.pprint(dictCountry)
# s_country = 'アメリカ合衆国'
# s_country = '北朝鮮'
# s_country = '中国'
# s_country = '中華人民共和国'
s_country = ''

# print_chiiki('アメリカ合衆国')
print_chiiki('神奈川県')

# https://us-central1-aerobic-factor-216914.cloudfunctions.net/function-4
# Out:
# done
# "神奈川県 ⇒（該当国名がありません）その他の地域\n['ろ地域', 'に地域①', 'に地域②', 'へ地域', 'と地域①', 'と地域②']"

# %%
### -*- coding:utf-8 -*-
# METI_chiiki.py

# https://pypi.org/project/html-table-extractor/
# これが便利そう
! pip install html-table-extractor
from html_table_extractor.extractor import Extractor

# 技術・貨物の提出書類の表への対応に書き換え中

# ＜技術＞http://www.meti.go.jp/policy/anpo/apply07.html
# ＜仕向＞http://www.meti.go.jp/policy/anpo/apply08.html
# ＜貨物＞http://www.meti.go.jp/policy/anpo/apply09.html
# 対象とする Web ページから決める記述は以下の３行。以下は
# 経産省の国と地域のページから地域の定義表を取り出すため
# に必要となる情報
'''
Surl = "http://www.meti.go.jp/policy/anpo/apply08.html"
Sdescription = "table"
Ddescription = {"class" : "style71"}
'''
Surl = "http://www.meti.go.jp/policy/anpo/apply07.html"
Ddescription = {"class" : "stype78" , "class" : "stype71" , "class" : "stype73" }
Nstart = 1
# 技術については表が整列されているので１行目から処理対象
# とすることができる。
# Surl = "http://www.meti.go.jp/policy/anpo/apply09.html"
# Ddescription = {"class" : "stype78"}
# Nstart = 2
# 貨物については表の整列が複雑なので、２行名から処理対象
# とするのがよさそう（１行目は表全体が１行になっており、
# 内容としては２行目以降にすべて現れる）

Sdescription = "table"

# https://qiita.com/hujuu/items/b0339404b8b0460087f9
# これを参考にさせていただきました。ありがとうございます。

import pprint
import csv
import requests
import bs4
import hashlib

''' ==== requirements.txt
# Function dependencies, for example:
# package>=version
# -# google-auth
google-api-python-client
oauth2client
bs4
'''

def print_chiiki():
  # URLを指定してコンテンツを取り出す
  #
  '''
html = urlopen("http://www.meti.go.jp/policy/anpo/apply08.html")
bsObj = BeautifulSoup(html, "html.parser")
# urlopenだとうまく動かないので、requests.get で .content を得るようにしました。
# これは
# https://orangain.hatenablog.com/entry/encoding-in-requests-and-beautiful-soup
# これを参考にさせていただきました。ありがとうございます。
# chardet も入れておいたほうがいいのかもしれませんが、今は入れてません。
  '''
  # 文法解析されたコンテンツを bsObj に入れておく
  # Surl = "http://www.meti.go.jp/policy/anpo/apply08.html"
  res = requests.get(Surl)
  res.raise_for_status()
  bsObj = bs4.BeautifulSoup(res.content , "html.parser")

  # テーブルを指定
  # table = bsObj.findAll("table",{"class":"tablesorter"})[0]
  # タグとクラスが該当するテーブルを tables に入れておく。
  # これは、WEBページの記述に依存するので都度調べる必要がある。
  # Sdescription = "table"
  # Ddescription = {"class" : "style71"}
  # tables = bsObj.findAll(Sdescription, Ddescription )
  # tables = bsObj.findAll(Sdescription,Ddescription)
  tables = bsObj.findAll(Sdescription)
  
  # pprint.pprint(tables)

  # csvFileName ='chiiki_work.csv'
  # csvFile = open(csvFileName , 'wt', newline = '', encoding = 'utf-8')
  # writer = csv.writer(csvFile)

  try:
    # 地域名（『と地域』とか）をキーとして国名のリストを値とした辞書
    dictChiiki = {}
    # 国名（『英国』とか）をキーとして属している地域のリスト（['と地域']とか）を値とした辞書
    dictCountry = {}

    '''
    # tables の要素としてひとつひとつの table ごとに
    for table in tables:

      # タグ《tr》により行（rows）を検出して
      rows = table.findAll("tr")
      # pprint.pprint(rows)
    '''
    #
    # extractor = Extractor(tables[1])
    extractor = Extractor(tables[Nstart - 1])
    extractor.parse()
    # pprint.pprint(extractor.return_list())
    extracted_table = extractor.return_list()
    for row in extracted_table :
      # pprint.pprint(type(row[2]))
      pprint.pprint(row)
      print(len(row))
      # print(row[2].lstrip().rstrip())
      # row[3]を『、』で区切る。『い地域』などが得られる。
      # 得られたものを key として、それ以外のカラムをうまく
      # value にする辞書を作ればいいのかな？
    #
  #
  finally:
    # csvFile.close()
    print('done')

print_chiiki()
# Out:
# ...
# ['\r\n          外為令別表の該当項番',
#  '\r\n          外為令別表の該当項番',
#  '\r\n          \xa0提供先国',
#  '\r\n          提出書類',
#  '\r\n          申請窓口']
# 5
# ['\r\n          １項',
#  '\n\r\n         １項\n\n\n輸出令別表第１の１項中欄に掲げる（以下「別１－各項番」と表記）貨物に係る技術',
#  '\r\n\t\t\t全地域',
#  '\nＴＥ',
#  '\n\n本省']
# 5
# ['\r\n          \r\n          ２項(1)',
#  '\n'
#  '２項（１）\n'
#  '別１－２（１）～（８）、（１０）、（１０の２）の貨物であって、\n'
#  '\r\n'
#  '\t\t\t・貨物等省令１条１号～５号（ただし、貨物等省令第１条第三号であって試薬又は標準物質として使用されるもの及び第四号ロを除く。）\n'
#  '・\xa0第六号（核燃料物質の成型加工用の装置に限る。）\n'
#  '・\xa0第七号\n'
#  '・\xa0第八号イ、第十号イ、第十号の二、第十号の三\n'
#  '\xa0\n'
#  'に該当する貨物に係る技術\n',
#  '\n\nい地域①',
#  '\n\r\n\t\t\tＴＢ１',
#  '\n\n本省']
# 5
# ['\r\n          \r\n          ２項(1)',
#  '\n'
#  '２項（１）\n'
#  '別１－２（１）～（８）、（１０）、（１０の２）の貨物であって、\n'
#  '\r\n'
#  '\t\t\t・貨物等省令１条１号～５号（ただし、貨物等省令第１条第三号であって試薬又は標準物質として使用されるもの及び第四号ロを除く。）\n'
#  '・\xa0第六号（核燃料物質の成型加工用の装置に限る。）\n'
#  '・\xa0第七号\n'
#  '・\xa0第八号イ、第十号イ、第十号の二、第十号の三\n'
#  '\xa0\n'
#  'に該当する貨物に係る技術\n',
#  '\n\nい地域②',
#  '\n\r\n\t\t\tＴＢ１',
#  '\n\n本省']
# ...

# %% [markdown]
# なかなか優秀な html_table_extractor だったのだが、どうしても表がうまく読み込めない。いったん方針転換して、google spread sheet と協力して処理することにしようと思う。
#
# 多くの処理は、表処理でもあるし。
# （ほかにも、国名の表記のゆれの吸収などで表処理が必要になりがち）

# %%
# -*- coding : utf-8 -*-

# https://tanuhack.com/python/operate-spreadsheet/
# あらかじめ秘密鍵のJSONデータをGCPで作っておき、そのファイルの
# json file の『\n』（書式として必要な改行を表すバックスラッシュ１文字とエヌ）
# は、『\\n』（バックスラッシュ２回とエヌ）に置き換えている。

# これで、ひとまずは、spread sheet 処理と連携できた。

client_secret_str ="""{
  "type": "service_account",
  "project_id": "aerobic-factor-216914",
  "private_key_id": "81f85d5d06da421bfd6f2e28e2c04a4696f41e2a",
  "private_key": "-----BEGIN PRIVATE KEY-----\\nMIIEvAIBADANBgkqhkiG9w0BAQEFAASCBKYwggSiAgEAAoIBAQC5Hpo9htA8tXmI\\nQZIJYotVPFMQHlVGnFsl5DYYjFM1aHMOSmr6VPS9RTR0iSp5eOZoxFH8EQoxtbee\\nuaibXJ0XeFKBFXnn0JQKI0bax+Ax9z2awhn50tId0+eap/ZAmXvWUWd9n0ZTFTCw\\nbei9G6xqgJqPpc9YodiSjDliKeGUVDJzPsuD6J13housDgA+xSJDb8Z6EF9Y71qT\\nEdm1AWRh29+PSle2nOBVQPAt0tlPNX3PQVhN2PzUpfVMrP6qzONW6lLQLoKHPrh6\\nOxwpKb3qETjjt0h37tTGCcf7e4HtrkIOvNsQlU1tO11iub+cLrGq2oaBRv9Q9JEN\\nzO2JLpwnAgMBAAECggEADzpMN8lyMbw/3gx+xdTcX0uSDZ5hJ2jPOqO2K3jHk3of\\nFMrcV/FLHJKnyPpLiyh905pqoBCKxSIMk7rz+qu4pGiaaNHqcD5BH0BdoLuWXqXW\\n5HcZCerkq911jMxKPnAhtrSFjdjfQRBaK/kujvfKzAv+KtjZ4JGXrh5ozgFh9ACA\\n+CEFzw09TklQo0JMwxc2fuxbQWnv0gN5gXOdwVo/0wZuH+yf5OMt7ICZsmRrj+jb\\n1ml5i2WgBWWiPGOxzNnHAPUI/P+lS/4akT4N3BbGOGxHckFRIuuzDOQdic3IOFVT\\n83LM8Xmp4OhCJUVGpUrpq6/TEHDVSscyaTYLP5nyeQKBgQD2+qWGxrGelPmhbopO\\nGBV+7eLTeBbGpCAlxzoBtxAGGybgckeFISilvSncNrS7znD2aUhBIC5/+xFMXFaw\\n5h+ttiJFP4rOqueiS3oHIb+vcOsjmaWtxiZZlRTpg9rQTsUdyQQYMzUF2Rdc+Uvl\\nMp9HzvKtg8UykOCUcP20nHoP9QKBgQC/4Ytbn8VX5bPbiikjVyvJmhSoRlizcY3v\\nX9pZxjGDopTXTYG3HL1d/JgjEP4EOXhrgshS7CyIk/tX4M/0kAi5FVvtv1YMTD84\\nyK0V4H4g76bHJgmnyhqiYxgtuedaSZlNpM01lEP1+DxcFU93O8G0GXjiJH+Uo8C7\\n3nY18yd2KwKBgFLULo0rt8fiWHHOW63jH9pot2iKXsERrAJfdVG77jDODFS7nsbE\\nHxiufwpugmB11KafGm9U9qNPNTbxxNUg6EDe01F8BPZYlMR2IZ+gruOMsB9JWSoV\\nSSlD+TZzVQAFWtApaSkgi0jBzLcOmGhueMKhYfvVNF5H/jlqR3u5+qm9AoGADcsB\\nwIFYpzvc1PA2itLOU/yedYYxBB0qjcV/JarojkTWnC93HpmTRzlMGmEzUUxsSpYp\\nHkTZ4qt4itWfPT5JUjyl0g5J+jJU7RkH0CXGC0oO3Avw773IclnbOBY/+i6GNZ2e\\nHrbct8azWA80GicSgoa+OMtU3HN0/Ew+hRxIfucCgYBjIRoYIDmyxxsVnPDmZjTI\\nDcF0y5xEcAEo85L5vTTy+y/RkDbUoTK8acKZtusCON8Gtu5UJh6v7wwIfONrmACS\\nd3IHVFy/ZFhBivTK3hSYigG0V8tAs23XFh/4fkWmbRF2MkLwxDw/SjnjVI0Rj+wR\\nhsAe/XX6LKZM8hXwP9MSMA==\\n-----END PRIVATE KEY-----\\n",
  "client_email": "python-colaboratory@aerobic-factor-216914.iam.gserviceaccount.com",
  "client_id": "115589074091830641206",
  "auth_uri": "https://accounts.google.com/o/oauth2/auth",
  "token_uri": "https://oauth2.googleapis.com/token",
  "auth_provider_x509_cert_url": "https://www.googleapis.com/oauth2/v1/certs",
  "client_x509_cert_url": "https://www.googleapis.com/robot/v1/metadata/x509/python-colaboratory%40aerobic-factor-216914.iam.gserviceaccount.com"
}
""" 
# '{"type": "service_account","project_id": "aerobic-factor-216914","private_key_id": "81f85d5d06da421bfd6f2e28e2c04a4696f41e2a","private_key": "-----BEGIN PRIVATE KEY-----\\n-----END PRIVATE KEY-----\n","client_email": "python-colaboratory@aerobic-factor-216914.iam.gserviceaccount.com","client_id": "115589074091830641206","auth_uri": "https://accounts.google.com/o/oauth2/auth","token_uri": "https://oauth2.googleapis.com/token","auth_provider_x509_cert_url": "https://www.googleapis.com/oauth2/v1/certs","client_x509_cert_url": "https://www.googleapis.com/robot/v1/metadata/x509/python-colaboratory%40aerobic-factor-216914.iam.gserviceaccount.com"}'

CLIENT_SECRET_FILE = 'client_secret.json'
with open(CLIENT_SECRET_FILE, mode='w') as f:
  f.write(client_secret_str)

import gspread
import json

# ServiceAccountCredentials：Googleの各サービスへアクセス
# できるservice変数を生成します。
from oauth2client.service_account import ServiceAccountCredentials 

# 2つのAPIを記述しないとリフレッシュトークンを3600秒毎に
# 発行し続けなければならない
scope = ['https://spreadsheets.google.com/feeds','https://www.googleapis.com/auth/drive']

# 認証情報設定
# ダウンロードしたjsonファイル名をクレデンシャル変数に設定
# （秘密鍵、Pythonファイルから読み込みしやすい位置に置く）
credentials = ServiceAccountCredentials.from_json_keyfile_name(CLIENT_SECRET_FILE, scope)
# credentials = ServiceAccountCredentials.from_json_keyfile_name('My Project 36945-81f85d5d06da.json' , scope)


# OAuth2の資格情報を使用してGoogle APIにログインします。
gc = gspread.authorize(credentials)

# 共有設定したスプレッドシートキーを
# 変数[SPREADSHEET_KEY]に格納する。
# SPREADSHEET_KEY = 'https://docs.google.com/spreadsheets/d/12rU27zXXAYPJ2VMh-lfJhGZjjXadSKDmV-iPy65Tx1M/edit?usp=sharing'
SPREADSHEET_URL = 'https://docs.google.com/spreadsheets/d/12rU27zXXAYPJ2VMh-lfJhGZjjXadSKDmV-iPy65Tx1M/edit?usp=sharing'

# 共有設定したスプレッドシートのシート1を開く
# worksheet = gc.open_by_key(SPREADSHEET_KEY).sheet1
worksheet = gc.open_by_url(SPREADSHEET_URL).sheet1

# シートに定義した計算式も python から書き込むことにすれば、
# 新規のシートに必要な計算式を、必要な数だけ定義しても
# 問題ない。
# それに、大きさがよくわからない表があったとしても、
# 『全部読み込み』とか『条件に合うセルのリストを作る』とか
# やりたいことがだいたいできちゃう。

# G8セルに URL を書き込み
# update_acell なら ('G8',value)
# update_cell なら (8,7,value)
# export_value = "http://www.meti.go.jp/policy/anpo/apply09.html"
export_value = "http://www.meti.go.jp/policy/anpo/apply07.html"
worksheet.update_acell('G8',export_value)
export_value = '=IMPORTHTML(G8,"table",1)'
worksheet.update_acell('G9',export_value)
# S8のセルの値（表のエントリー数）を読み込む
import_value = worksheet.acell('S8').value
print(import_value)

# A1セルの値に100加算した値をB1セルに表示させる
# export_value = import_value+100
# worksheet.update_cell(1,2, export_value)
# Out:
# 67

# %%
import pprint
CLIENT_SECRET_FILE = 'My Project 36945-81f85d5d06da.json'
with open(CLIENT_SECRET_FILE, mode='r') as f:
  client_secret_str = f.read()
pprint.pprint(client_secret_str)
# Out:
# ('{\n'
#  '  "type": "service_account",\n'
#  '  "project_id": "aerobic-factor-216914",\n'
#  '  "private_key_id": "81f85d5d06da421bfd6f2e28e2c04a4696f41e2a",\n'
#  '  "private_key": "-----BEGIN PRIVATE '
# ...

# %%
import pprint
CLIENT_SECRET_FILE = 'client_secret.json'
with open(CLIENT_SECRET_FILE, mode='r') as f:
  client_secret_str = f.read()
pprint.pprint(client_secret_str)
# Out:
# ('{\n'
#  '  "type": "service_account",\n'
#  '  "project_id": "aerobic-factor-216914",\n'
#  '  "private_key_id": "81f85d5d06da421bfd6f2e28e2c04a4696f41e2a",\n'
#  '  "private_key": "-----BEGIN PRIVATE KEY-----\n'
#  'MIIEvAIBADANBgkqhkiG9w0BAQEFAASCBKYwggSiAgEAAoIBAQC5Hpo9htA8tXmI\n'
#  'QZIJYotVPFMQHlVGnFsl5DYYjFM1aHMOSmr6VPS9RTR0iSp5eOZoxFH8EQoxtbee\n'
#  'uaibXJ0XeFKBFXnn0JQKI0bax+Ax9z2awhn50tId0+eap/ZAmXvWUWd9n0ZTFTCw\n'
#  'bei9G6xqgJqPpc9YodiSjDliKeGUVDJzPsuD6J13housDgA+xSJDb8Z6EF9Y71qT\n'
#  'Edm1AWRh29+PSle2nOBVQPAt0tlPNX3PQVhN2PzUpfVMrP6qzONW6lLQLoKHPrh6\n'
#  'OxwpKb3qETjjt0h37tTGCcf7e4HtrkIOvNsQlU1tO11iub+cLrGq2oaBRv9Q9JEN\n'
#  'zO2JLpwnAgMBAAECggEADzpMN8lyMbw/3gx+xdTcX0uSDZ5hJ2jPOqO2K3jHk3of\n'
#  'FMrcV/FLHJKnyPpLiyh905pqoBCKxSIMk7rz+qu4pGiaaNHqcD5BH0BdoLuWXqXW\n'
#  '5HcZCerkq911jMxKPnAhtrSFjdjfQRBaK/kujvfKzAv+KtjZ4JGXrh5ozgFh9ACA\n'
#  '+CEFzw09TklQo0JMwxc2fuxbQWnv0gN5gXOdwVo/0wZuH+yf5OMt7ICZsmRrj+jb\n'
# ...

# %%
# -*- coding : utf-8 -*-

# ということで、新規セルを作る方法でやってみよう。

# https://tanuhack.com/python/operate-spreadsheet/
# あらかじめ秘密鍵のJSONデータをGCPで作っておき、そのファイルの
# json file の『\n』（書式として必要な改行を表すバックスラッシュ１文字とエヌ）
# は、『\\n』（バックスラッシュ２回とエヌ）に置き換えている。

# これで、ひとまずは、spread sheet 処理と連携できた。

client_secret_str ="""{
  "type": "service_account",
  "project_id": "aerobic-factor-216914",
  "private_key_id": "81f85d5d06da421bfd6f2e28e2c04a4696f41e2a",
  "private_key": "-----BEGIN PRIVATE KEY-----\\nMIIEvAIBADANBgkqhkiG9w0BAQEFAASCBKYwggSiAgEAAoIBAQC5Hpo9htA8tXmI\\nQZIJYotVPFMQHlVGnFsl5DYYjFM1aHMOSmr6VPS9RTR0iSp5eOZoxFH8EQoxtbee\\nuaibXJ0XeFKBFXnn0JQKI0bax+Ax9z2awhn50tId0+eap/ZAmXvWUWd9n0ZTFTCw\\nbei9G6xqgJqPpc9YodiSjDliKeGUVDJzPsuD6J13housDgA+xSJDb8Z6EF9Y71qT\\nEdm1AWRh29+PSle2nOBVQPAt0tlPNX3PQVhN2PzUpfVMrP6qzONW6lLQLoKHPrh6\\nOxwpKb3qETjjt0h37tTGCcf7e4HtrkIOvNsQlU1tO11iub+cLrGq2oaBRv9Q9JEN\\nzO2JLpwnAgMBAAECggEADzpMN8lyMbw/3gx+xdTcX0uSDZ5hJ2jPOqO2K3jHk3of\\nFMrcV/FLHJKnyPpLiyh905pqoBCKxSIMk7rz+qu4pGiaaNHqcD5BH0BdoLuWXqXW\\n5HcZCerkq911jMxKPnAhtrSFjdjfQRBaK/kujvfKzAv+KtjZ4JGXrh5ozgFh9ACA\\n+CEFzw09TklQo0JMwxc2fuxbQWnv0gN5gXOdwVo/0wZuH+yf5OMt7ICZsmRrj+jb\\n1ml5i2WgBWWiPGOxzNnHAPUI/P+lS/4akT4N3BbGOGxHckFRIuuzDOQdic3IOFVT\\n83LM8Xmp4OhCJUVGpUrpq6/TEHDVSscyaTYLP5nyeQKBgQD2+qWGxrGelPmhbopO\\nGBV+7eLTeBbGpCAlxzoBtxAGGybgckeFISilvSncNrS7znD2aUhBIC5/+xFMXFaw\\n5h+ttiJFP4rOqueiS3oHIb+vcOsjmaWtxiZZlRTpg9rQTsUdyQQYMzUF2Rdc+Uvl\\nMp9HzvKtg8UykOCUcP20nHoP9QKBgQC/4Ytbn8VX5bPbiikjVyvJmhSoRlizcY3v\\nX9pZxjGDopTXTYG3HL1d/JgjEP4EOXhrgshS7CyIk/tX4M/0kAi5FVvtv1YMTD84\\nyK0V4H4g76bHJgmnyhqiYxgtuedaSZlNpM01lEP1+DxcFU93O8G0GXjiJH+Uo8C7\\n3nY18yd2KwKBgFLULo0rt8fiWHHOW63jH9pot2iKXsERrAJfdVG77jDODFS7nsbE\\nHxiufwpugmB11KafGm9U9qNPNTbxxNUg6EDe01F8BPZYlMR2IZ+gruOMsB9JWSoV\\nSSlD+TZzVQAFWtApaSkgi0jBzLcOmGhueMKhYfvVNF5H/jlqR3u5+qm9AoGADcsB\\nwIFYpzvc1PA2itLOU/yedYYxBB0qjcV/JarojkTWnC93HpmTRzlMGmEzUUxsSpYp\\nHkTZ4qt4itWfPT5JUjyl0g5J+jJU7RkH0CXGC0oO3Avw773IclnbOBY/+i6GNZ2e\\nHrbct8azWA80GicSgoa+OMtU3HN0/Ew+hRxIfucCgYBjIRoYIDmyxxsVnPDmZjTI\\nDcF0y5xEcAEo85L5vTTy+y/RkDbUoTK8acKZtusCON8Gtu5UJh6v7wwIfONrmACS\\nd3IHVFy/ZFhBivTK3hSYigG0V8tAs23XFh/4fkWmbRF2MkLwxDw/SjnjVI0Rj+wR\\nhsAe/XX6LKZM8hXwP9MSMA==\\n-----END PRIVATE KEY-----\\n",
  "client_email": "python-colaboratory@aerobic-factor-216914.iam.gserviceaccount.com",
  "client_id": "115589074091830641206",
  "auth_uri": "https://accounts.google.com/o/oauth2/auth",
  "token_uri": "https://oauth2.googleapis.com/token",
  "auth_provider_x509_cert_url": "https://www.googleapis.com/oauth2/v1/certs",
  "client_x509_cert_url": "https://www.googleapis.com/robot/v1/metadata/x509/python-colaboratory%40aerobic-factor-216914.iam.gserviceaccount.com"
}
""" 
# '{"type": "service_account","project_id": "aerobic-factor-216914","private_key_id": "81f85d5d06da421bfd6f2e28e2c04a4696f41e2a","private_key": "-----BEGIN PRIVATE KEY-----\\n-----END PRIVATE KEY-----\n","client_email": "python-colaboratory@aerobic-factor-216914.iam.gserviceaccount.com","client_id": "115589074091830641206","auth_uri": "https://accounts.google.com/o/oauth2/auth","token_uri": "https://oauth2.googleapis.com/token","auth_provider_x509_cert_url": "https://www.googleapis.com/oauth2/v1/certs","client_x509_cert_url": "https://www.googleapis.com/robot/v1/metadata/x509/python-colaboratory%40aerobic-factor-216914.iam.gserviceaccount.com"}'

CLIENT_SECRET_FILE = 'client_secret.json'
with open(CLIENT_SECRET_FILE, mode='w') as f:
  f.write(client_secret_str)

import gspread
import json
import re
import pprint

# ServiceAccountCredentials：Googleの各サービスへアクセス
# できるservice変数を生成します。
from oauth2client.service_account import ServiceAccountCredentials 

# 2つのAPIを記述しないとリフレッシュトークンを3600秒毎に
# 発行し続けなければならない
scope = ['https://spreadsheets.google.com/feeds','https://www.googleapis.com/auth/drive']

# 認証情報設定
# ダウンロードしたjsonファイル名をクレデンシャル変数に設定
# （秘密鍵、Pythonファイルから読み込みしやすい位置に置く）
credentials = ServiceAccountCredentials.from_json_keyfile_name(CLIENT_SECRET_FILE, scope)
# credentials = ServiceAccountCredentials.from_json_keyfile_name('My Project 36945-81f85d5d06da.json' , scope)


# OAuth2の資格情報を使用してGoogle APIにログインします。
gc = gspread.authorize(credentials)

# 共有設定したスプレッドシートキーを
# 変数[SPREADSHEET_KEY]に格納する。
# SPREADSHEET_KEY = 'https://docs.google.com/spreadsheets/d/12rU27zXXAYPJ2VMh-lfJhGZjjXadSKDmV-iPy65Tx1M/edit?usp=sharing'
# SPREADSHEET_URL = 'https://docs.google.com/spreadsheets/d/12rU27zXXAYPJ2VMh-lfJhGZjjXadSKDmV-iPy65Tx1M/edit?usp=sharing'

# 共有設定したスプレッドシートのシート1を開く
# worksheet = gc.open_by_key(SPREADSHEET_KEY).sheet1
# worksheet = gc.open_by_url(SPREADSHEET_URL).sheet1
try:
  sh = gc.open('tmp_render_gs')
except APIError as e:
  sh = gc.create('tmp_render_gs')
  sh.share('aokit.aecl@gmail.com', perm_type='user', role='writer')
finally:
  worksheet = sh.sheet1

# シートに定義した計算式も python から書き込むことにすれば、
# 新規のシートに必要な計算式を、必要な数だけ定義しても
# 問題ない。
# それに、大きさがよくわからない表があったとしても、
# 『全部読み込み』とか『条件に合うセルのリストを作る』とか
# やりたいことがだいたいできちゃう。

# G8セルに URL を書き込み
# update_acell なら ('G8',value)
# update_cell なら (8,7,value)
# export_value = "http://www.meti.go.jp/policy/anpo/apply09.html"
export_value = "http://www.meti.go.jp/policy/anpo/apply09.html"
worksheet.update_acell('B1',export_value)
export_value = '=IMPORTHTML(B1,"table")'
# 貨物は "table",1 だと持ってこられないみたい・・・
worksheet.update_acell('B2',export_value)
# S8のセルの値（表のエントリー数）を読み込む
# import_value = worksheet.acell('S8').value
# print(import_value)
list_of_lists = worksheet.get_all_values()
# pprint.pprint(list_of_lists)
# print(len(list_of_lists))


nr = len(list_of_lists)
# print(nr)
ir = 0
last_item = ''
list_of_lists_comp = []
while ir < nr :
  if list_of_lists[ir][1] == '' :
    if list_of_lists[ir][2] == '' :
      list_of_lists[ir][0] = last_item
    else :
      list_of_lists[ir][0] = list_of_lists[ir][2]
  else :
    list_of_lists[ir][0] = list_of_lists[ir][1]
  last_item = list_of_lists[ir][0]
  ir = ir + 1
   
pprint.pprint(list_of_lists)    

# amount_re = re.compile(r'い地域①')
amount_re = re.compile(r'は地域①')
cell_list = worksheet.findall(amount_re)
print(len(cell_list))
for cell in cell_list :
  # print(cell.row)
  nc  = cell.col - 1
  nr  = cell.row - 1
  # c9  = worksheet.cell(cell.row , nc - 2).value
  # pprint.pprint(list_of_lists[nr])
  c9 = list_of_lists[nr][0]
  # print(c9)
  # c11 = worksheet.cell(cell.row , nc + 1).value
  c11 = list_of_lists[nr][nc + 1]
  # print(c11)
  # c12 = worksheet.cell(cell.row , nc + 2).value
  c12 = list_of_lists[nr][nc + 2]
  # print(c12)
  print(pprint.pformat(cell.row) + "：" + pprint.pformat(c9) + "：" + c11 + "：" + c12)

# A1セルの値に100加算した値をB1セルに表示させる
# export_value = import_value+100
# worksheet.update_cell(1,2, export_value)

export_formula = '''=if(isblank(indirect("R[0]C[-6]",false)),
                          if(isblank(indirect("R[0]C[-5]",false)),
                               indirect("R[-1]C[0]",false),
                             indirect("R[0]C[-5]",false)),
                        indirect("R[0]C[-6]",false))'''
# worksheet.update_acell('H3' , export_formula)
#
'''式を定義：すぐ右、それが空白ならその右、両方空白なら
   真上の値を持ってくる。
'''
a9_formula = '''
  =if(isblank(indirect("R[0]C[1]",false)),
     if(isblank(indirect("R[0]C[2]",false)),
         indirect("R[-1]C[0]",false),
       indirect("R[0]C[2]",false)),
     indirect("R[0]C[1]",false))'''

'''式を定義：すぐ右、それが空白なら真上の値を持ってくる。
'''
a7_formula = '''=if(isblank(indirect("R[0]C[1]",false)),
      indirect("R[-1]C[0]",false),
    indirect("R[0]C[1]",false))'''

cells = worksheet.range('A1:A100')
'''
for cell in cells:
	cell.formula = a7_formula
#
worksheet.update_cells(cells)
'''
for cell in cells:
  cell.formula = a7_formula
# これ、１００回のイベントを spread sheet に発行している
# ことになるので、1秒で100回という制約にかかってしまう
# 場合がある。
# やっぱりしかたがないので、表のうえに大量の計算式を
# 集中的に設定するは避けることにする。

# worksheet.update_acell('A3',a7_formula)
'''
# for cell in cells:
#   worksheet.update_cell(cell.row, cell.col, a7_formula)
#
worksheet.update_cell(1, 1, a7_formula)
worksheet.update_cell(2, 1, a7_formula)
worksheet.update_cell(3, 1, a7_formula)
worksheet.update_cell(4, 1, a7_formula)
worksheet.update_cell(5, 1, a7_formula)
'''
# Out:
# [['http://www.meti.go.jp/policy/anpo/apply09.html',
#   'http://www.meti.go.jp/policy/anpo/apply09.html',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['輸出令別表第１の該当項番', '輸出令別表第１の該当項番', '', '', '仕 向 地', '提出書類', '申請窓口'],
#  ['１項',
#   '１項',
#   '',
#   '１項\n'
#   '\n'
#   ' \n'
#   '\n'
#   '（１）に掲げる貨物で、次のいずれかに該当するもの\n'
#   '\n'
#   '（イ）空気銃、散弾銃、ライフル銃又は火縄式銃砲であって、スポーツ用又は狩猟用のもの\n'
#   '\n'
#   '（ロ）救命銃、もり銃、リベット銃その他これらに類する産業用銃\n'
#   '\n'
#   '（ハ）（イ）に掲げるものに用いる銃砲弾\n'
#   '\n'
#   '（ニ）（イ）及び（ロ）に掲げるものの附属品（暗視機能を有する装置を除く。）\n'
#   '\n'
#   '（ホ）（イ）から（ニ）までに掲げるものの部分品\n'
#   '\n'
#   '（２）に掲げる貨物であって、産業用の発破器\n'
#   '（３）に掲げる貨物のうち、産業用の火薬若しくは爆薬又はこれらの火工品',
#   '全地域',
#   'Ｅ２',
#   '経済産業局'],
#  ['１項', '', '', '１項\n\n \n\n上記以外の貨物', '全地域', 'Ｅ１', '本省'],
#  ['２項',
#   '２項',
#   '２項\n'
#   '\n'
#   '（３）、（４）、（６）、（８）、（１０）に掲げる貨物で、次のいずれかに該当するもの\n'
#   '\n'
#   '・貨物等省令第１条第三号（試薬又は標準物質として使用されるもののうち、輸出申告の際の重水素の原子質量の総量が１キログラム未満のものに限る。）\n'
#   '\n'
#   '・第四号ロ\n'
#   '\n'
#   '・第六号（リチウムの同位元素の分離用の装置に限る。）\n'
#   '・第八号ロ又は第十号ロ',
# ...

# %% [markdown]
# 表組みの乱れをどのように修正するか。結局のところ、spread sheet で計算式を定義するのは、GCP の制約に抵触してしまうみたいなので、pythonの側で行うことにした。
# 貨物と技術で表組みの乱れの補正が違うのが厄介だけれどしかたないかな。

# %%
# -*- coding : utf-8 -*-

# ということで、新規セルを作る方法でやってみよう。

# https://tanuhack.com/python/operate-spreadsheet/
# あらかじめ秘密鍵のJSONデータをGCPで作っておき、そのファイルの
# json file の『\n』（書式として必要な改行を表すバックスラッシュ１文字とエヌ）
# は、『\\n』（バックスラッシュ２回とエヌ）に置き換えている。

# これで、ひとまずは、spread sheet 処理と連携できた。

client_secret_str ="""{
  "type": "service_account",
  "project_id": "aerobic-factor-216914",
  "private_key_id": "81f85d5d06da421bfd6f2e28e2c04a4696f41e2a",
  "private_key": "-----BEGIN PRIVATE KEY-----\\nMIIEvAIBADANBgkqhkiG9w0BAQEFAASCBKYwggSiAgEAAoIBAQC5Hpo9htA8tXmI\\nQZIJYotVPFMQHlVGnFsl5DYYjFM1aHMOSmr6VPS9RTR0iSp5eOZoxFH8EQoxtbee\\nuaibXJ0XeFKBFXnn0JQKI0bax+Ax9z2awhn50tId0+eap/ZAmXvWUWd9n0ZTFTCw\\nbei9G6xqgJqPpc9YodiSjDliKeGUVDJzPsuD6J13housDgA+xSJDb8Z6EF9Y71qT\\nEdm1AWRh29+PSle2nOBVQPAt0tlPNX3PQVhN2PzUpfVMrP6qzONW6lLQLoKHPrh6\\nOxwpKb3qETjjt0h37tTGCcf7e4HtrkIOvNsQlU1tO11iub+cLrGq2oaBRv9Q9JEN\\nzO2JLpwnAgMBAAECggEADzpMN8lyMbw/3gx+xdTcX0uSDZ5hJ2jPOqO2K3jHk3of\\nFMrcV/FLHJKnyPpLiyh905pqoBCKxSIMk7rz+qu4pGiaaNHqcD5BH0BdoLuWXqXW\\n5HcZCerkq911jMxKPnAhtrSFjdjfQRBaK/kujvfKzAv+KtjZ4JGXrh5ozgFh9ACA\\n+CEFzw09TklQo0JMwxc2fuxbQWnv0gN5gXOdwVo/0wZuH+yf5OMt7ICZsmRrj+jb\\n1ml5i2WgBWWiPGOxzNnHAPUI/P+lS/4akT4N3BbGOGxHckFRIuuzDOQdic3IOFVT\\n83LM8Xmp4OhCJUVGpUrpq6/TEHDVSscyaTYLP5nyeQKBgQD2+qWGxrGelPmhbopO\\nGBV+7eLTeBbGpCAlxzoBtxAGGybgckeFISilvSncNrS7znD2aUhBIC5/+xFMXFaw\\n5h+ttiJFP4rOqueiS3oHIb+vcOsjmaWtxiZZlRTpg9rQTsUdyQQYMzUF2Rdc+Uvl\\nMp9HzvKtg8UykOCUcP20nHoP9QKBgQC/4Ytbn8VX5bPbiikjVyvJmhSoRlizcY3v\\nX9pZxjGDopTXTYG3HL1d/JgjEP4EOXhrgshS7CyIk/tX4M/0kAi5FVvtv1YMTD84\\nyK0V4H4g76bHJgmnyhqiYxgtuedaSZlNpM01lEP1+DxcFU93O8G0GXjiJH+Uo8C7\\n3nY18yd2KwKBgFLULo0rt8fiWHHOW63jH9pot2iKXsERrAJfdVG77jDODFS7nsbE\\nHxiufwpugmB11KafGm9U9qNPNTbxxNUg6EDe01F8BPZYlMR2IZ+gruOMsB9JWSoV\\nSSlD+TZzVQAFWtApaSkgi0jBzLcOmGhueMKhYfvVNF5H/jlqR3u5+qm9AoGADcsB\\nwIFYpzvc1PA2itLOU/yedYYxBB0qjcV/JarojkTWnC93HpmTRzlMGmEzUUxsSpYp\\nHkTZ4qt4itWfPT5JUjyl0g5J+jJU7RkH0CXGC0oO3Avw773IclnbOBY/+i6GNZ2e\\nHrbct8azWA80GicSgoa+OMtU3HN0/Ew+hRxIfucCgYBjIRoYIDmyxxsVnPDmZjTI\\nDcF0y5xEcAEo85L5vTTy+y/RkDbUoTK8acKZtusCON8Gtu5UJh6v7wwIfONrmACS\\nd3IHVFy/ZFhBivTK3hSYigG0V8tAs23XFh/4fkWmbRF2MkLwxDw/SjnjVI0Rj+wR\\nhsAe/XX6LKZM8hXwP9MSMA==\\n-----END PRIVATE KEY-----\\n",
  "client_email": "python-colaboratory@aerobic-factor-216914.iam.gserviceaccount.com",
  "client_id": "115589074091830641206",
  "auth_uri": "https://accounts.google.com/o/oauth2/auth",
  "token_uri": "https://oauth2.googleapis.com/token",
  "auth_provider_x509_cert_url": "https://www.googleapis.com/oauth2/v1/certs",
  "client_x509_cert_url": "https://www.googleapis.com/robot/v1/metadata/x509/python-colaboratory%40aerobic-factor-216914.iam.gserviceaccount.com"
}
""" 
# '{"type": "service_account","project_id": "aerobic-factor-216914","private_key_id": "81f85d5d06da421bfd6f2e28e2c04a4696f41e2a","private_key": "-----BEGIN PRIVATE KEY-----\\n-----END PRIVATE KEY-----\n","client_email": "python-colaboratory@aerobic-factor-216914.iam.gserviceaccount.com","client_id": "115589074091830641206","auth_uri": "https://accounts.google.com/o/oauth2/auth","token_uri": "https://oauth2.googleapis.com/token","auth_provider_x509_cert_url": "https://www.googleapis.com/oauth2/v1/certs","client_x509_cert_url": "https://www.googleapis.com/robot/v1/metadata/x509/python-colaboratory%40aerobic-factor-216914.iam.gserviceaccount.com"}'

CLIENT_SECRET_FILE = 'client_secret.json'
with open(CLIENT_SECRET_FILE, mode='w') as f:
  f.write(client_secret_str)

import gspread
import json
import re
import pprint

# ServiceAccountCredentials：Googleの各サービスへアクセス
# できるservice変数を生成します。
from oauth2client.service_account import ServiceAccountCredentials 

# 2つのAPIを記述しないとリフレッシュトークンを3600秒毎に
# 発行し続けなければならない
scope = ['https://spreadsheets.google.com/feeds','https://www.googleapis.com/auth/drive']

# 認証情報設定
# ダウンロードしたjsonファイル名をクレデンシャル変数に設定
# （秘密鍵、Pythonファイルから読み込みしやすい位置に置く）
credentials = ServiceAccountCredentials.from_json_keyfile_name(CLIENT_SECRET_FILE, scope)
# credentials = ServiceAccountCredentials.from_json_keyfile_name('My Project 36945-81f85d5d06da.json' , scope)

# OAuth2の資格情報を使用してGoogle APIにログインします。
gc = gspread.authorize(credentials)

# 共有設定したスプレッドシートキーを
# 変数[SPREADSHEET_KEY]に格納する。
# SPREADSHEET_KEY = 'https://docs.google.com/spreadsheets/d/12rU27zXXAYPJ2VMh-lfJhGZjjXadSKDmV-iPy65Tx1M/edit?usp=sharing'
# SPREADSHEET_URL = 'https://docs.google.com/spreadsheets/d/12rU27zXXAYPJ2VMh-lfJhGZjjXadSKDmV-iPy65Tx1M/edit?usp=sharing'

# 共有設定したスプレッドシートのシート1を開く
# worksheet = gc.open_by_key(SPREADSHEET_KEY).sheet1
# worksheet = gc.open_by_url(SPREADSHEET_URL).sheet1
try:
  sh = gc.open('tmp_render_gs')
  # worksheet = sh.add_worksheet(title="tmp",rows=256,cols=32)
  # sh.del_worksheet(sh.sheet1)
except APIError as e:
  sh = gc.create('tmp_render_gs')
  sh.share('aokit.aecl@gmail.com', perm_type='user', role='writer')
finally:
  worksheet = sh.sheet1
  
worksheet.clear()

# シートに定義した計算式も python から書き込むことにすれば、
# 新規のシートに必要な計算式を、必要な数だけ定義しても
# 問題ない。
# それに、大きさがよくわからない表があったとしても、
# 『全部読み込み』とか『条件に合うセルのリストを作る』とか
# やりたいことがだいたいできちゃう。

# G8セルに URL を書き込み
# update_acell なら ('G8',value)
# update_cell なら (8,7,value)
# export_value = "http://www.meti.go.jp/policy/anpo/apply09.html"
export_value = "http://www.meti.go.jp/policy/anpo/apply09.html"
worksheet.update_acell('B1',export_value)
export_value = '=IMPORTHTML(B1,"table")'
# 貨物は "table",1 だと持ってこられないみたい・・・
worksheet.update_acell('B2',export_value)
# S8のセルの値（表のエントリー数）を読み込む
# import_value = worksheet.acell('S8').value
# print(import_value)
list_of_lists = worksheet.get_all_values()
# pprint.pprint(list_of_lists)
# print(len(list_of_lists))

'''式を定義：すぐ右、それが空白ならその右、両方空白なら
   真上の値を持ってくる。
'''
nr = len(list_of_lists)
# print(nr)
ir = 0
last_item = ''
list_of_lists_comp = []
while ir < nr :
  if list_of_lists[ir][1] == '' :
    if list_of_lists[ir][2] == '' :
      list_of_lists[ir][0] = last_item
    else :
      list_of_lists[ir][0] = list_of_lists[ir][2]
  else :
    list_of_lists[ir][0] = list_of_lists[ir][1]
  last_item = list_of_lists[ir][0]
  ir = ir + 1
   
pprint.pprint(list_of_lists)    

# amount_re = re.compile(r'い地域①')
amount_re = re.compile(r'は地域①')
cell_list = worksheet.findall(amount_re)
print(len(cell_list))
for cell in cell_list :
  # print(cell.row)
  nc  = cell.col - 1
  nr  = cell.row - 1
  # c9  = worksheet.cell(cell.row , nc - 2).value
  # pprint.pprint(list_of_lists[nr])
  c9 = list_of_lists[nr][0]
  # print(c9)
  # c11 = worksheet.cell(cell.row , nc + 1).value
  c11 = list_of_lists[nr][nc + 1]
  # print(c11)
  # c12 = worksheet.cell(cell.row , nc + 2).value
  c12 = list_of_lists[nr][nc + 2]
  # print(c12)
  print(pprint.pformat(cell.row) + "：" + pprint.pformat(c9) + "：" + c11 + "：" + c12)

a9_formula = '''
  =if(isblank(indirect("R[0]C[1]",false)),
     if(isblank(indirect("R[0]C[2]",false)),
         indirect("R[-1]C[0]",false),
       indirect("R[0]C[2]",false)),
     indirect("R[0]C[1]",false))'''

'''式を定義：すぐ右、それが空白なら真上の値を持ってくる。
'''
a7_formula = '''=if(isblank(indirect("R[0]C[1]",false)),
      indirect("R[-1]C[0]",false),
    indirect("R[0]C[1]",false))'''
'''
cells = worksheet.range('A1:A100')
#
for cell in cells:
	cell.formula = a7_formula
#
worksheet.update_cells(cells)
#
for cell in cells:
  cell.formula = a7_formula
# これ、１００回のイベントを spread sheet に発行している
# ことになるので、1秒で100回という制約にかかってしまう
# 場合がある。
# やっぱりしかたがないので、表のうえに大量の計算式を
# 集中的に設定するは避けることにする。

# worksheet.update_acell('A3',a7_formula)
#
# for cell in cells:
#   worksheet.update_cell(cell.row, cell.col, a7_formula)
#
worksheet.update_cell(1, 1, a7_formula)
worksheet.update_cell(2, 1, a7_formula)
worksheet.update_cell(3, 1, a7_formula)
worksheet.update_cell(4, 1, a7_formula)
worksheet.update_cell(5, 1, a7_formula)
'''
# Out:
# [['http://www.meti.go.jp/policy/anpo/apply09.html',
#   'http://www.meti.go.jp/policy/anpo/apply09.html',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['輸出令別表第１の該当項番', '輸出令別表第１の該当項番', '', '', '仕 向 地', '提出書類', '申請窓口'],
#  ['１項',
#   '１項',
#   '',
#   '１項\n'
#   '\n'
#   ' \n'
#   '\n'
#   '（１）に掲げる貨物で、次のいずれかに該当するもの\n'
#   '\n'
#   '（イ）空気銃、散弾銃、ライフル銃又は火縄式銃砲であって、スポーツ用又は狩猟用のもの\n'
#   '\n'
#   '（ロ）救命銃、もり銃、リベット銃その他これらに類する産業用銃\n'
#   '\n'
#   '（ハ）（イ）に掲げるものに用いる銃砲弾\n'
#   '\n'
#   '（ニ）（イ）及び（ロ）に掲げるものの附属品（暗視機能を有する装置を除く。）\n'
#   '\n'
#   '（ホ）（イ）から（ニ）までに掲げるものの部分品\n'
#   '\n'
#   '（２）に掲げる貨物であって、産業用の発破器\n'
#   '（３）に掲げる貨物のうち、産業用の火薬若しくは爆薬又はこれらの火工品',
#   '全地域',
#   'Ｅ２',
#   '経済産業局'],
#  ['１項', '', '', '１項\n\n \n\n上記以外の貨物', '全地域', 'Ｅ１', '本省'],
#  ['２項',
#   '２項',
#   '２項\n'
#   '\n'
#   '（３）、（４）、（６）、（８）、（１０）に掲げる貨物で、次のいずれかに該当するもの\n'
#   '\n'
#   '・貨物等省令第１条第三号（試薬又は標準物質として使用されるもののうち、輸出申告の際の重水素の原子質量の総量が１キログラム未満のものに限る。）\n'
#   '\n'
#   '・第四号ロ\n'
#   '\n'
#   '・第六号（リチウムの同位元素の分離用の装置に限る。）\n'
#   '・第八号ロ又は第十号ロ',
# ...
